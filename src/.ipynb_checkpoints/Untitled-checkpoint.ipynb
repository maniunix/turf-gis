# %%
import geopandas as gpd
import turfpy

# %%
geojson_path = "../task.geojson"
gdf = gpd.read_file(geojson_path)

# %%
# Out:
#                                LAYER                              geometry
# 0   Détection des 33 déchets QGIS V2   POINT Z (4.77783 50.61652 46.01733)
# 1   Détection des 33 déchets QGIS V2   POINT Z (4.77732 50.61580 46.01785)
# 2   Détection des 33 déchets QGIS V2   POINT Z (4.77628 50.61551 46.01745)
# 3   Détection des 33 déchets QGIS V2   POINT Z (4.77649 50.61911 46.01331)
# 4   Détection des 33 déchets QGIS V2   POINT Z (4.77705 50.61868 46.01421)
# 5   Détection des 33 déchets QGIS V2   POINT Z (4.77676 50.61817 46.01461)
# 6   Détection des 33 déchets QGIS V2   POINT Z (4.77731 50.61815 46.01503)
# 7   Détection des 33 déchets QGIS V2   POINT Z (4.77744 50.61803 46.01526)
# 8   Détection des 33 déchets QGIS V2   POINT Z (4.77744 50.61803 46.01527)
# 9   Détection des 33 déchets QGIS V2   POINT Z (4.77746 50.61801 46.01530)
# 10  Détection des 33 déchets QGIS V2   POINT Z (4.77746 50.61801 46.01529)
# ...
